# %% [markdown]
# ## Write a Numpy program to compute the multiplication of two given matrixes

# %%
import numpy as np
mat_1=np.arange(1,10).reshape(3,3)
mat_2=np.arange(1,10).reshape(3,3)

# %%
#element-wise mult
print(mat_1*mat_2)
#dot product
print(mat_1.dot(mat_2))
# Out:
# [[ 1  4  9]
#  [16 25 36]
#  [49 64 81]]
# [[ 30  36  42]
#  [ 66  81  96]
#  [102 126 150]]

# %% [markdown]
# ## Write a NumPy program to compute the determinant of a given square array

# %%
mat_3=np.arange(1,10).reshape(3,3)

# %%
print(np.linalg.det(mat_1))
# Out:
# 0.0

# %% [markdown]
# ## Write a NumPy program to compute the cross product of two given vectors

# %%
vec_1=np.array([1,2,3])
vec_2=np.array([4,5,6])

# %%
print(np.cross(vec_1,vec_2))
# Out:
# [-3  6 -3]

# %% [markdown]
# ## Write a NumPy program to compute the condition number of a given matrix
# the condition number of a function measures how much the output value of the function can change for a small change in the input argument. This is used to measure how sensitive a function is to changes or errors in the input, and how much error in the output results from an error in the input.
#
# *hint: look for something similar in the `linalg` module*

# %%
mat_4=np.arange(1,10).reshape(3,3)

# %%
print(np.linalg.cond(mat_4))
# Out:
# 5.0522794445385096e+16

# %% [markdown]
# ## Write a NumPy program to compute the inverse of a given matrix

# %%
mat_5=np.array=([[1,2],
                [5,9]])

# %%
print(np.linalg.inv(mat_5))
# Out:
# [[-9.  2.]
#  [ 5. -1.]]
